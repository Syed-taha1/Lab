# %%
#Reading Tiff Images
import rasterio
from rasterio.plot import show
from PIL import Image
img = Image.open("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")
show(img)
pixels = img.load()

# %%
#Meta Data About Tiff Images
import rasterio

# Open the GeoTIFF image
with rasterio.open("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
    
dataset.count
dataset.width
dataset.height

import matplotlib.pyplot as plt
plt.imshow(img)
# Out:
# Image Size (Width x Height): 5600 x 4700
# Number of Bands: 1

# %%
import numpy as np
from PIL import Image

# Open the image
img = Image.open("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")

# Convert the image to a NumPy array
img_array = np.array(img)

# Calculate image statistics
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)

# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)

width, height = img.size

# Print the results
print("Width:", width)
print("Height:", height)
# Out:
# Mean: 4293.927958016718
# Standard Deviation: 2078.3364604917524
# Min: 0
# Max: 65535
# Width: 5600
# Height: 4700

# %%
#Reducing Size of the image
import matplotlib.pyplot as plt
import cv2
import numpy as np

 
try:
    img = cv2.imread("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif") 
    (height, width) = img.shape[:2]    
    res = cv2.resize(img, (int(width / 4), int(height / 4)), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tiff', res)
    plt.imshow(res)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Rotating Tiff Images
try:
    img = cv2.imread("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")
    (rows, cols) = img.shape[:2]
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 180, 1)
    res1 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res1)
    plt.imshow(res1)
except IOError:
    print('Error while reading files !!!')

# %%
#Translating Matrix
M = np.float32([[1, 0, 100], [0, 1, 50]])
try:
    img = cv2.imread("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")
    res2 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res2)
    plt.imshow(res2)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Canny Edge Detection
try:
    img = cv2.imread("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")
    edges = cv2.Canny(img, 15, 10)
    cv2.imwrite('result.tiff', edges)
    plt.imshow(edges)

except IOError:
    print('Error while reading files !!!')

# %%
#RGB
import cv2
import matplotlib.pyplot as plt

img2 = cv2.imread("C:\\Users\\B-Tech\\Downloads\\ALPSRP247640500-H2.2_UA\\HH-ALPSRP247640500-H2.2_UA.tif")
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.imshow(img2_rgb)
plt.axis('off')  
plt.show()
